# %% [markdown]
# # U-Net  +  CapsNet  =  UCaps!

# %% [markdown]
# * Testing a simple **U-Net** on Montgomery_Dataset

# %%
import os
import numpy as np
import cv2
import tensorflow as tf
from sklearn.model_selection import StratifiedKFold
from sklearn.metrics import confusion_matrix, accuracy_score, recall_score, precision_score, f1_score
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.figure_factory as ff

# Directories for Montgomery dataset images and masks
image_dir = r'C:\Users\Jaber\OneDrive - University of Florida\Educational\GitHub\Datasets\ImageSegmentation\Montgomery_Dataset\CXR_png'
left_mask_dir = r'C:\Users\Jaber\OneDrive - University of Florida\Educational\GitHub\Datasets\ImageSegmentation\Montgomery_Dataset\Masks_png\leftMask'
right_mask_dir = r'C:\Users\Jaber\OneDrive - University of Florida\Educational\GitHub\Datasets\ImageSegmentation\Montgomery_Dataset\Masks_png\rightMask'

img_size = (256, 256)

def load_images_and_masks(image_dir, left_mask_dir, right_mask_dir, img_size):
    images = []
    masks = []
    
    for img_name in os.listdir(image_dir):
        img_path = os.path.join(image_dir, img_name)
        left_mask_path = os.path.join(left_mask_dir, img_name)
        right_mask_path = os.path.join(right_mask_dir, img_name)
        
        img = cv2.imread(img_path, cv2.IMREAD_GRAYSCALE)
        if img is None:
            print(f"Image not found: {img_path}")
            continue
        
        img = cv2.resize(img, img_size)
        img = img / 255.0  # Normalize image to range 0-1
        
        left_mask = cv2.imread(left_mask_path, cv2.IMREAD_GRAYSCALE)
        right_mask = cv2.imread(right_mask_path, cv2.IMREAD_GRAYSCALE)
        
        if left_mask is None or right_mask is None:
            print(f"Mask not found: {left_mask_path} or {right_mask_path}")
            continue
        
        left_mask = cv2.resize(left_mask, img_size)
        right_mask = cv2.resize(right_mask, img_size)
        
        combined_mask = np.maximum(left_mask, right_mask)
        combined_mask = combined_mask / 255.0  # Normalize mask to range 0-1
        
        images.append(np.expand_dims(img, axis=-1))  # Add channel dimension to the image
        masks.append(np.expand_dims(combined_mask, axis=-1))  # Add channel dimension to the mask
    
    return np.array(images), np.array(masks)

# Load the images and combined masks
images, masks = load_images_and_masks(image_dir, left_mask_dir, right_mask_dir, img_size)

# Ensure data was loaded correctly
if len(images) == 0 or len(masks) == 0:
    raise ValueError("No images or masks were loaded. Check the dataset paths and file names.")

# U-Net Architecture
def unet_model(input_size=(256, 256, 1)):
    inputs = tf.keras.layers.Input(input_size)
    
    # Contracting Path
    c1 = tf.keras.layers.Conv2D(64, 3, activation='relu', padding='same')(inputs)
    c1 = tf.keras.layers.Conv2D(64, 3, activation='relu', padding='same')(c1)
    p1 = tf.keras.layers.MaxPooling2D(pool_size=(2, 2))(c1)
    
    c2 = tf.keras.layers.Conv2D(128, 3, activation='relu', padding='same')(p1)
    c2 = tf.keras.layers.Conv2D(128, 3, activation='relu', padding='same')(c2)
    p2 = tf.keras.layers.MaxPooling2D(pool_size=(2, 2))(c2)
    
    c3 = tf.keras.layers.Conv2D(256, 3, activation='relu', padding='same')(p2)
    c3 = tf.keras.layers.Conv2D(256, 3, activation='relu', padding='same')(c3)
    p3 = tf.keras.layers.MaxPooling2D(pool_size=(2, 2))(c3)
    
    # Bottleneck
    b = tf.keras.layers.Conv2D(512, 3, activation='relu', padding='same')(p3)
    b = tf.keras.layers.Conv2D(512, 3, activation='relu', padding='same')(b)
    
    # Expansive Path
    u1 = tf.keras.layers.Conv2DTranspose(256, 2, strides=(2, 2), padding='same')(b)
    u1 = tf.keras.layers.concatenate([u1, c3])
    c4 = tf.keras.layers.Conv2D(256, 3, activation='relu', padding='same')(u1)
    c4 = tf.keras.layers.Conv2D(256, 3, activation='relu', padding='same')(c4)
    
    u2 = tf.keras.layers.Conv2DTranspose(128, 2, strides=(2, 2), padding='same')(c4)
    u2 = tf.keras.layers.concatenate([u2, c2])
    c5 = tf.keras.layers.Conv2D(128, 3, activation='relu', padding='same')(u2)
    c5 = tf.keras.layers.Conv2D(128, 3, activation='relu', padding='same')(c5)
    
    u3 = tf.keras.layers.Conv2DTranspose(64, 2, strides=(2, 2), padding='same')(c5)
    u3 = tf.keras.layers.concatenate([u3, c1])
    c6 = tf.keras.layers.Conv2D(64, 3, activation='relu', padding='same')(u3)
    c6 = tf.keras.layers.Conv2D(64, 3, activation='relu', padding='same')(c6)
    
    outputs = tf.keras.layers.Conv2D(1, 1, activation='sigmoid')(c6)
    
    model = tf.keras.Model(inputs=[inputs], outputs=[outputs])
    return model

# Dice and Binary Crossentropy combined loss function
def combined_dice_bce_loss(y_true, y_pred):
    # Flatten the predictions and true labels
    y_true_f = tf.keras.backend.flatten(y_true)
    y_pred_f = tf.keras.backend.flatten(y_pred)
    
    # Dice coefficient
    intersection = tf.keras.backend.sum(y_true_f * y_pred_f)
    dice_loss = 1 - (2. * intersection + 1) / (tf.keras.backend.sum(y_true_f) + tf.keras.backend.sum(y_pred_f) + 1)
    
    # Binary crossentropy
    bce_loss = tf.keras.losses.binary_crossentropy(y_true_f, y_pred_f)
    
    # Combine Dice and BCE losses
    return dice_loss + bce_loss

# Learning rate scheduler
def lr_scheduler(epoch, lr):
    if epoch > 10:
        lr = lr * 0.5  # Reduce learning rate after 10 epochs
    return lr

# Early stopping callback to avoid overfitting
early_stopping = tf.keras.callbacks.EarlyStopping(monitor='val_loss', patience=5, restore_best_weights=True)
lr_callback = tf.keras.callbacks.LearningRateScheduler(lr_scheduler)

# Stratified K-Fold setup to ensure class distribution is similar across folds
kf = StratifiedKFold(n_splits=3, shuffle=True, random_state=42)

# Arrays to store performance metrics for each fold
accuracy_scores = []
recall_scores = []
precision_scores = []
f1_scores = []
specificity_scores = []

# Create a flattened version of masks to ensure stratified splitting (since KFold expects a 1D array)
masks_flattened = masks.reshape((masks.shape[0], -1)).mean(axis=1).astype(int)

# Track history for visualization
train_histories = []

# Loop through each fold in the 3-fold cross-validation
fold = 1
for train_index, test_index in kf.split(images, masks_flattened):
    X_train, X_test = images[train_index], images[test_index]
    y_train, y_test = masks[train_index], masks[test_index]
    
    # Create the model for each fold
    model = unet_model()
    model.compile(optimizer='adam', loss=combined_dice_bce_loss, metrics=['accuracy'])
    
    # Train the model with early stopping and learning rate scheduler
    history = model.fit(X_train, y_train, validation_data=(X_test, y_test), epochs=50, batch_size=8, 
                        callbacks=[early_stopping, lr_callback], verbose=1)
    
    # Save history for plotting
    train_histories.append(history.history)
    
    # Predict on the test set
    y_pred = model.predict(X_test)
    
    # Adjust threshold for binary prediction (tune if needed)
    threshold = 0.5
    y_pred = (y_pred > threshold).astype(np.uint8)  # Ensure binary predictions
    
    y_test_binary = (y_test > threshold).astype(np.uint8)  # Convert y_test to binary for comparison

    # Calculate performance metrics for this fold
    def calculate_metrics(y_true, y_pred):
        y_true_flat = y_true.flatten()
        y_pred_flat = y_pred.flatten()
        
        accuracy = accuracy_score(y_true_flat, y_pred_flat)
        recall = recall_score(y_true_flat, y_pred_flat)
        precision = precision_score(y_true_flat, y_pred_flat)
        f1 = f1_score(y_true_flat, y_pred_flat)
        
        tn, fp, fn, tp = confusion_matrix(y_true_flat, y_pred_flat).ravel()
        specificity = tn / (tn + fp)
        
        return accuracy, recall, precision, f1, specificity

    # Calculate metrics for this fold
    accuracy, recall, precision, f1, specificity = calculate_metrics(y_test_binary, y_pred)
    
    # Append metrics to the respective arrays
    accuracy_scores.append(accuracy)
    recall_scores.append(recall)
    precision_scores.append(precision)
    f1_scores.append(f1)
    specificity_scores.append(specificity)

    # Plot confusion matrix for this fold
    conf_matrix = confusion_matrix(y_test_binary.flatten(), y_pred.flatten())
    sns.heatmap(conf_matrix, annot=True, fmt="d", cmap="Blues")
    plt.title(f"Confusion Matrix for Fold {fold}")
    plt.show()

    # Visualize predictions for this fold
    for i in range(3):  # Visualize first 3 predictions
        fig, ax = plt.subplots(1, 3, figsize=(15, 5))
        
        ax[0].imshow(X_test[i].squeeze(), cmap='gray')
        ax[0].set_title('Input Image')
        
        ax[1].imshow(y_test[i].squeeze(), cmap='gray')
        ax[1].set_title('True Mask')
        
        ax[2].imshow(y_pred[i].squeeze(), cmap='gray')
        ax[2].set_title('Predicted Mask')
        
        plt.show()
    
    fold += 1

# Calculate the average performance across all 3 folds
avg_accuracy = np.mean(accuracy_scores)
avg_recall = np.mean(recall_scores)
avg_precision = np.mean(precision_scores)
avg_f1 = np.mean(f1_scores)
avg_specificity = np.mean(specificity_scores)

# Print the average performance metrics
print(f'Average Accuracy: {avg_accuracy:.4f}')
print(f'Average Recall (Sensitivity): {avg_recall:.4f}')
print(f'Average Precision: {avg_precision:.4f}')
print(f'Average F1 Score: {avg_f1:.4f}')
print(f'Average Specificity: {avg_specificity:.4f}')

# Plot training history
for fold_idx, history in enumerate(train_histories):
    plt.figure(figsize=(12, 5))
    plt.subplot(1, 2, 1)
    plt.plot(history['accuracy'], label='Train Accuracy')
    plt.plot(history['val_accuracy'], label='Val Accuracy')
    plt.title(f'Model Accuracy for Fold {fold_idx + 1}')
    plt.xlabel('Epoch')
    plt.ylabel('Accuracy')
    plt.legend()

    plt.subplot(1, 2, 2)
    plt.plot(history['loss'], label='Train Loss')
    plt.plot(history['val_loss'], label='Val Loss')
    plt.title(f'Model Loss for Fold {fold_idx + 1}')
    plt.xlabel('Epoch')
    plt.ylabel('Loss')
    plt.legend()

    plt.tight_layout()
    plt.show()
# Out:
# Epoch 1/50
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 198s 16s/step - accuracy: 0.7253 - loss: 1.2901 - val_accuracy: 0.7503 - val_loss: 1.1281 - learning_rate: 0.0010
# Epoch 2/50
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 188s 16s/step - accuracy: 0.7403 - loss: 1.0417 - val_accuracy: 0.7503 - val_loss: 0.8475 - learning_rate: 0.0010
# Epoch 3/50
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 198s 17s/step - accuracy: 0.8230 - loss: 0.8214 - val_accuracy: 0.9187 - val_loss: 0.7307 - learning_rate: 0.0010
# Epoch 4/50
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 192s 16s/step - accuracy: 0.9226 - loss: 0.6888 - val_accuracy: 0.9249 - val_loss: 0.4081 - learning_rate: 0.0010
# Epoch 5/50
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 211s 18s/step - accuracy: 0.9307 - loss: 0.3676 - val_accuracy: 0.9358 - val_loss: 0.3477 - learning_rate: 0.0010
# Epoch 6/50
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 205s 17s/step - accuracy: 0.9392 - loss: 0.3241 - val_accuracy: 0.9423 - val_loss: 0.3137 - learning_rate: 0.0010
# Epoch 7/50
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 198s 17s/step - accuracy: 0.9481 - loss: 0.2759 - val_accuracy: 0.9451 - val_loss: 0.2916 - learning_rate: 0.0010
# Epoch 8/50
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 210s 18s/step - accuracy: 0.9531 - loss: 0.2527 - val_accuracy: 0.9413 - val_loss: 0.3018 - learning_rate: 0.0010
# Epoch 9/50
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 188s 16s/step - accuracy: 0.9535 - loss: 0.2478 - val_accuracy: 0.9570 - val_loss: 0.2403 - learning_rate: 0.0010
# Epoch 10/50
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 204s 17s/step - accuracy: 0.9615 - loss: 0.2089 - val_accuracy: 0.9564 - val_loss: 0.2488 - learning_rate: 0.0010
# Epoch 11/50
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 256s 16s/step - accuracy: 0.9630 - loss: 0.2004 - val_accuracy: 0.9441 - val_loss: 0.2812 - learning_rate: 0.0010
# Epoch 12/50
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 197s 17s/step - accuracy: 0.9617 - loss: 0.2045 - val_accuracy: 0.9652 - val_loss: 0.1988 - learning_rate: 5.0000e-04
# Epoch 13/50
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 202s 17s/step - accuracy: 0.9684 - loss: 0.1780 - val_accuracy: 0.9673 - val_loss: 0.1833 - learning_rate: 2.5000e-04
# Epoch 14/50
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 195s 16s/step - accuracy: 0.9716 - loss: 0.1549 - val_accuracy: 0.9697 - val_loss: 0.1692 - learning_rate: 1.2500e-04
# Epoch 15/50
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 196s 16s/step - accuracy: 0.9751 - loss: 0.1339 - val_accuracy: 0.9712 - val_loss: 0.1622 - learning_rate: 6.2500e-05
# Epoch 16/50
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 195s 16s/step - accuracy: 0.9769 - loss: 0.1261 - val_accuracy: 0.9711 - val_loss: 0.1609 - learning_rate: 3.1250e-05
# Epoch 17/50
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 194s 16s/step - accuracy: 0.9755 - loss: 0.1324 - val_accuracy: 0.9715 - val_loss: 0.1591 - learning_rate: 1.5625e-05
# Epoch 18/50
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 194s 16s/step - accuracy: 0.9771 - loss: 0.1239 - val_accuracy: 0.9717 - val_loss: 0.1585 - learning_rate: 7.8125e-06
# Epoch 19/50
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 184s 15s/step - accuracy: 0.9749 - loss: 0.1374 - val_accuracy: 0.9716 - val_loss: 0.1584 - learning_rate: 3.9063e-06
# Epoch 20/50
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 182s 15s/step - accuracy: 0.9750 - loss: 0.1383 - val_accuracy: 0.9716 - val_loss: 0.1584 - learning_rate: 1.9531e-06
# Epoch 21/50
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 177s 15s/step - accuracy: 0.9748 - loss: 0.1362 - val_accuracy: 0.9716 - val_loss: 0.1583 - learning_rate: 9.7656e-07
# Epoch 22/50
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 180s 15s/step - accuracy: 0.9775 - loss: 0.1219 - val_accuracy: 0.9716 - val_loss: 0.1583 - learning_rate: 4.8828e-07
# Epoch 23/50
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 176s 15s/step - accuracy: 0.9783 - loss: 0.1174 - val_accuracy: 0.9716 - val_loss: 0.1582 - learning_rate: 2.4414e-07
# Epoch 24/50
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 181s 15s/step - accuracy: 0.9768 - loss: 0.1253 - val_accuracy: 0.9716 - val_loss: 0.1582 - learning_rate: 1.2207e-07
# Epoch 25/50
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 178s 15s/step - accuracy: 0.9774 - loss: 0.1231 - val_accuracy: 0.9716 - val_loss: 0.1582 - learning_rate: 6.1035e-08
# Epoch 26/50
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 178s 15s/step - accuracy: 0.9770 - loss: 0.1280 - val_accuracy: 0.9716 - val_loss: 0.1582 - learning_rate: 3.0518e-08
# Epoch 27/50
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 176s 15s/step - accuracy: 0.9776 - loss: 0.1206 - val_accuracy: 0.9716 - val_loss: 0.1582 - learning_rate: 1.5259e-08
# Epoch 28/50
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 182s 15s/step - accuracy: 0.9775 - loss: 0.1220 - val_accuracy: 0.9716 - val_loss: 0.1582 - learning_rate: 7.6294e-09
# Epoch 29/50
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 196s 15s/step - accuracy: 0.9779 - loss: 0.1205 - val_accuracy: 0.9716 - val_loss: 0.1582 - learning_rate: 3.8147e-09
# Epoch 30/50
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 176s 15s/step - accuracy: 0.9755 - loss: 0.1332 - val_accuracy: 0.9716 - val_loss: 0.1582 - learning_rate: 1.9073e-09
# Epoch 31/50
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 201s 15s/step - accuracy: 0.9779 - loss: 0.1208 - val_accuracy: 0.9716 - val_loss: 0.1582 - learning_rate: 9.5367e-10
# Epoch 32/50
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 178s 15s/step - accuracy: 0.9770 - loss: 0.1232 - val_accuracy: 0.9716 - val_loss: 0.1582 - learning_rate: 4.7684e-10
# Epoch 33/50
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 175s 15s/step - accuracy: 0.9756 - loss: 0.1360 - val_accuracy: 0.9716 - val_loss: 0.1582 - learning_rate: 2.3842e-10
# Epoch 34/50
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 179s 15s/step - accuracy: 0.9769 - loss: 0.1275 - val_accuracy: 0.9716 - val_loss: 0.1582 - learning_rate: 1.1921e-10
# Epoch 35/50
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 179s 15s/step - accuracy: 0.9758 - loss: 0.1327 - val_accuracy: 0.9716 - val_loss: 0.1582 - learning_rate: 5.9605e-11
# Epoch 36/50
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 177s 15s/step - accuracy: 0.9756 - loss: 0.1318 - val_accuracy: 0.9716 - val_loss: 0.1582 - learning_rate: 2.9802e-11
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 12s 4s/step
# Epoch 1/50
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 185s 15s/step - accuracy: 0.7327 - loss: 1.2985 - val_accuracy: 0.7379 - val_loss: 1.1535 - learning_rate: 0.0010
# Epoch 2/50
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 180s 15s/step - accuracy: 0.7494 - loss: 1.0292 - val_accuracy: 0.7379 - val_loss: 0.8123 - learning_rate: 0.0010
# Epoch 3/50
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 175s 15s/step - accuracy: 0.8104 - loss: 0.8433 - val_accuracy: 0.9138 - val_loss: 0.7561 - learning_rate: 0.0010
# Epoch 4/50
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 183s 15s/step - accuracy: 0.9181 - loss: 0.6942 - val_accuracy: 0.9305 - val_loss: 0.3983 - learning_rate: 0.0010
# Epoch 5/50
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 180s 15s/step - accuracy: 0.9284 - loss: 0.3772 - val_accuracy: 0.9112 - val_loss: 0.4543 - learning_rate: 0.0010
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 17s 6s/step
# C:\ProgramData\Anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# Epoch 1/50
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 222s 18s/step - accuracy: 0.7140 - loss: 1.2966 - val_accuracy: 0.7440 - val_loss: 1.1826 - learning_rate: 0.0010
# Epoch 2/50
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 197s 16s/step - accuracy: 0.7468 - loss: 1.0653 - val_accuracy: 0.7440 - val_loss: 1.1404 - learning_rate: 0.0010
# Epoch 3/50
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 215s 18s/step - accuracy: 0.7786 - loss: 0.9513 - val_accuracy: 0.9106 - val_loss: 0.7238 - learning_rate: 0.0010
# Epoch 4/50
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 208s 17s/step - accuracy: 0.9123 - loss: 0.6554 - val_accuracy: 0.9191 - val_loss: 0.5446 - learning_rate: 0.0010
# Epoch 5/50
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 175s 15s/step - accuracy: 0.9270 - loss: 0.4157 - val_accuracy: 0.9392 - val_loss: 0.3325 - learning_rate: 0.0010
# WARNING:tensorflow:5 out of the last 5 calls to <function TensorFlowTrainer.make_predict_function.<locals>.one_step_on_data_distributed at 0x0000022E7069C5E0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 1/2 ━━━━━━━━━━━━━━━━━━━━ 13s 13s/stepWARNING:tensorflow:6 out of the last 6 calls to <function TensorFlowTrainer.make_predict_function.<locals>.one_step_on_data_distributed at 0x0000022E7069C5E0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 17s 4s/step
# C:\ProgramData\Anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# Average Accuracy: 0.8183
# Average Recall (Sensitivity): 0.3125
# Average Precision: 0.3166
# Average F1 Score: 0.3145
# Average Specificity: 0.9945

# %% [markdown]
# ### Testing **UCaps** on Montgomery_Dataset

# %%
import os
import numpy as np
import cv2
import tensorflow as tf
from sklearn.model_selection import StratifiedKFold
from sklearn.metrics import confusion_matrix, accuracy_score, recall_score, precision_score, f1_score
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.figure_factory as ff

# Directories for Montgomery dataset images and masks
image_dir = r'C:\Users\Jaber\OneDrive - University of Florida\Educational\GitHub\Datasets\ImageSegmentation\Montgomery_Dataset\CXR_png'
left_mask_dir = r'C:\Users\Jaber\OneDrive - University of Florida\Educational\GitHub\Datasets\ImageSegmentation\Montgomery_Dataset\Masks_png\leftMask'
right_mask_dir = r'C:\Users\Jaber\OneDrive - University of Florida\Educational\GitHub\Datasets\ImageSegmentation\Montgomery_Dataset\Masks_png\rightMask'

img_size = (256, 256)

def load_images_and_masks(image_dir, left_mask_dir, right_mask_dir, img_size):
    images = []
    masks = []
    
    for img_name in os.listdir(image_dir):
        img_path = os.path.join(image_dir, img_name)
        left_mask_path = os.path.join(left_mask_dir, img_name)
        right_mask_path = os.path.join(right_mask_dir, img_name)
        
        img = cv2.imread(img_path, cv2.IMREAD_GRAYSCALE)
        if img is None:
            print(f"Image not found: {img_path}")
            continue
        
        img = cv2.resize(img, img_size)
        img = img / 255.0  # Normalize image to range 0-1
        
        left_mask = cv2.imread(left_mask_path, cv2.IMREAD_GRAYSCALE)
        right_mask = cv2.imread(right_mask_path, cv2.IMREAD_GRAYSCALE)
        
        if left_mask is None or right_mask is None:
            print(f"Mask not found: {left_mask_path} or {right_mask_path}")
            continue
        
        left_mask = cv2.resize(left_mask, img_size)
        right_mask = cv2.resize(right_mask, img_size)
        
        combined_mask = np.maximum(left_mask, right_mask)
        combined_mask = combined_mask / 255.0  # Normalize mask to range 0-1
        
        images.append(np.expand_dims(img, axis=-1))  # Add channel dimension to the image
        masks.append(np.expand_dims(combined_mask, axis=-1))  # Add channel dimension to the mask
    
    return np.array(images), np.array(masks)

# Load the images and combined masks
images, masks = load_images_and_masks(image_dir, left_mask_dir, right_mask_dir, img_size)

# Ensure data was loaded correctly
if len(images) == 0 or len(masks) == 0:
    raise ValueError("No images or masks were loaded. Check the dataset paths and file names.")

# Capsule Layer with Dynamic Routing
from tensorflow.keras import layers

def squash(vectors, axis=-1):
    """Squashing function to ensure output vectors' lengths are between 0 and 1"""
    s_squared_norm = tf.reduce_sum(tf.square(vectors), axis, keepdims=True)
    scale = s_squared_norm / (1 + s_squared_norm) / tf.sqrt(s_squared_norm + tf.keras.backend.epsilon())
    return scale * vectors

class CapsuleLayer(layers.Layer):
    def __init__(self, num_capsules, dim_capsule, num_routing=3, **kwargs):
        super(CapsuleLayer, self).__init__(**kwargs)
        self.num_capsules = num_capsules
        self.dim_capsule = dim_capsule
        self.num_routing = num_routing

    def build(self, input_shape):
        # Define the weight matrix W for transformation between input and capsule dimensions
        self.W = self.add_weight(shape=[input_shape[-1], self.num_capsules * self.dim_capsule],
                                 initializer='glorot_uniform', trainable=True)

    def call(self, inputs):
        inputs = tf.reshape(inputs, [-1, inputs.shape[1] * inputs.shape[2], inputs.shape[3]])
        u_hat = tf.einsum('...ij,jk->...ik', inputs, self.W)
        u_hat = tf.reshape(u_hat, [-1, inputs.shape[1], self.num_capsules, self.dim_capsule])
        
        b = tf.zeros(shape=[tf.shape(inputs)[0], inputs.shape[1], self.num_capsules])
        for i in range(self.num_routing):
            c = tf.nn.softmax(b, axis=-1)
            s = tf.reduce_sum(c[..., tf.newaxis] * u_hat, axis=1)
            v = squash(s)
            if i < self.num_routing - 1:
                b += tf.reduce_sum(u_hat * v[:, tf.newaxis, :, :], axis=-1)
        return v

# U-Net with Capsule Network Layers and Dynamic Routing
def unet_capsule_model(input_size=(256, 256, 1)):
    inputs = tf.keras.layers.Input(input_size)
    
    # Contracting Path with Capsules
    c1 = tf.keras.layers.Conv2D(64, 3, activation='relu', padding='same')(inputs)
    c1 = CapsuleLayer(num_capsules=8, dim_capsule=16)(c1)
    c1_flattened = tf.keras.layers.Flatten()(c1)  # Flatten the capsule output
    c1_reshaped = tf.keras.layers.Dense(256*256, activation='relu')(c1_flattened)  # Fully connected layer to reshape
    c1_reshaped = tf.keras.layers.Reshape((256, 256, 1))(c1_reshaped)  # Reshape to 4D
    p1 = tf.keras.layers.MaxPooling2D(pool_size=(2, 2))(c1_reshaped)
    
    c2 = tf.keras.layers.Conv2D(128, 3, activation='relu', padding='same')(p1)
    c2 = CapsuleLayer(num_capsules=16, dim_capsule=32)(c2)
    c2_flattened = tf.keras.layers.Flatten()(c2)
    c2_reshaped = tf.keras.layers.Dense(128*128, activation='relu')(c2_flattened)
    c2_reshaped = tf.keras.layers.Reshape((128, 128, 1))(c2_reshaped)
    p2 = tf.keras.layers.MaxPooling2D(pool_size=(2, 2))(c2_reshaped)
    
    c3 = tf.keras.layers.Conv2D(256, 3, activation='relu', padding='same')(p2)
    c3 = CapsuleLayer(num_capsules=32, dim_capsule=64)(c3)
    c3_flattened = tf.keras.layers.Flatten()(c3)
    c3_reshaped = tf.keras.layers.Dense(64*64, activation='relu')(c3_flattened)
    c3_reshaped = tf.keras.layers.Reshape((64, 64, 1))(c3_reshaped)
    p3 = tf.keras.layers.MaxPooling2D(pool_size=(2, 2))(c3_reshaped)
    
    # Bottleneck
    b = tf.keras.layers.Conv2D(512, 3, activation='relu', padding='same')(p3)
    b = tf.keras.layers.Conv2D(512, 3, activation='relu', padding='same')(b)
    
    # Expansive Path (kept similar to original U-Net)
    u1 = tf.keras.layers.Conv2DTranspose(256, 2, strides=(2, 2), padding='same')(b)
    u1 = tf.keras.layers.concatenate([u1, c3_reshaped])
    c4 = tf.keras.layers.Conv2D(256, 3, activation='relu', padding='same')(u1)
    c4 = tf.keras.layers.Conv2D(256, 3, activation='relu', padding='same')(c4)
    
    u2 = tf.keras.layers.Conv2DTranspose(128, 2, strides=(2, 2), padding='same')(c4)
    u2 = tf.keras.layers.concatenate([u2, c2_reshaped])
    c5 = tf.keras.layers.Conv2D(128, 3, activation='relu', padding='same')(u2)
    c5 = tf.keras.layers.Conv2D(128, 3, activation='relu', padding='same')(c5)
    
    u3 = tf.keras.layers.Conv2DTranspose(64, 2, strides=(2, 2), padding='same')(c5)
    u3 = tf.keras.layers.concatenate([u3, c1_reshaped])
    c6 = tf.keras.layers.Conv2D(64, 3, activation='relu', padding='same')(u3)
    c6 = tf.keras.layers.Conv2D(64, 3, activation='relu', padding='same')(c6)
    
    outputs = tf.keras.layers.Conv2D(1, 1, activation='sigmoid')(c6)
    
    model = tf.keras.Model(inputs=[inputs], outputs=[outputs])
    return model

# Dice and Binary Crossentropy combined loss function
def combined_dice_bce_loss(y_true, y_pred):
    # Flatten the predictions and true labels
    y_true_f = tf.keras.backend.flatten(y_true)
    y_pred_f = tf.keras.backend.flatten(y_pred)
    
    # Dice coefficient
    intersection = tf.keras.backend.sum(y_true_f * y_pred_f)
    dice_loss = 1 - (2. * intersection + 1) / (tf.keras.backend.sum(y_true_f) + tf.keras.backend.sum(y_pred_f) + 1)
    
    # Binary crossentropy
    bce_loss = tf.keras.losses.binary_crossentropy(y_true_f, y_pred_f)
    
    # Combine Dice and BCE losses
    return dice_loss + bce_loss

# Learning rate scheduler
def lr_scheduler(epoch, lr):
    if epoch > 10:
        lr = lr * 0.5  # Reduce learning rate after 10 epochs
    return lr

# Early stopping callback to avoid overfitting
early_stopping = tf.keras.callbacks.EarlyStopping(monitor='val_loss', patience=5, restore_best_weights=True)
lr_callback = tf.keras.callbacks.LearningRateScheduler(lr_scheduler)

# Stratified K-Fold setup to ensure class distribution is similar across folds
kf = StratifiedKFold(n_splits=3, shuffle=True, random_state=42)

# Arrays to store performance metrics for each fold
accuracy_scores = []
recall_scores = []
precision_scores = []
f1_scores = []
specificity_scores = []

# Create a flattened version of masks to ensure stratified splitting (since KFold expects a 1D array)
masks_flattened = masks.reshape((masks.shape[0], -1)).mean(axis=1).astype(int)

# Track history for visualization
train_histories = []

# Loop through each fold in the 3-fold cross-validation
fold = 1
for train_index, test_index in kf.split(images, masks_flattened):
    X_train, X_test = images[train_index], images[test_index]
    y_train, y_test = masks[train_index], masks[test_index]
    
    # Create the model for each fold
    model = unet_capsule_model()
    model.compile(optimizer='adam', loss=combined_dice_bce_loss, metrics=['accuracy'])
    
    # Train the model with early stopping and learning rate scheduler
    history = model.fit(X_train, y_train, validation_data=(X_test, y_test), epochs=50, batch_size=8, 
                        callbacks=[early_stopping, lr_callback], verbose=1)
    
    # Save history for plotting
    train_histories.append(history.history)
    
    # Predict on the test set
    y_pred = model.predict(X_test)
    
    # Adjust threshold for binary prediction (tune if needed)
    threshold = 0.5
    y_pred = (y_pred > threshold).astype(np.uint8)  # Ensure binary predictions
    
    y_test_binary = (y_test > threshold).astype(np.uint8)  # Convert y_test to binary for comparison

    # Calculate performance metrics for this fold
    def calculate_metrics(y_true, y_pred):
        y_true_flat = y_true.flatten()
        y_pred_flat = y_pred.flatten()
        
        accuracy = accuracy_score(y_true_flat, y_pred_flat)
        recall = recall_score(y_true_flat, y_pred_flat)
        precision = precision_score(y_true_flat, y_pred_flat)
        f1 = f1_score(y_true_flat, y_pred_flat)
        
        tn, fp, fn, tp = confusion_matrix(y_true_flat, y_pred_flat).ravel()
        specificity = tn / (tn + fp)
        
        return accuracy, recall, precision, f1, specificity

    # Calculate metrics for this fold
    accuracy, recall, precision, f1, specificity = calculate_metrics(y_test_binary, y_pred)
    
    # Append metrics to the respective arrays
    accuracy_scores.append(accuracy)
    recall_scores.append(recall)
    precision_scores.append(precision)
    f1_scores.append(f1)
    specificity_scores.append(specificity)

    # Plot confusion matrix for this fold
    conf_matrix = confusion_matrix(y_test_binary.flatten(), y_pred.flatten())
    sns.heatmap(conf_matrix, annot=True, fmt="d", cmap="Blues")
    plt.title(f"Confusion Matrix for Fold {fold}")
    plt.show()

    # Visualize predictions for this fold
    for i in range(3):  # Visualize first 3 predictions
        fig, ax = plt.subplots(1, 3, figsize=(15, 5))
        
        ax[0].imshow(X_test[i].squeeze(), cmap='gray')
        ax[0].set_title('Input Image')
        
        ax[1].imshow(y_test[i].squeeze(), cmap='gray')
        ax[1].set_title('True Mask')
        
        ax[2].imshow(y_pred[i].squeeze(), cmap='gray')
        ax[2].set_title('Predicted Mask')
        
        plt.show()
    
    fold += 1

# Calculate the average performance across all 3 folds
avg_accuracy = np.mean(accuracy_scores)
avg_recall = np.mean(recall_scores)
avg_precision = np.mean(precision_scores)
avg_f1 = np.mean(f1_scores)
avg_specificity = np.mean(specificity_scores)

# Print the average performance metrics
print(f'Average Accuracy: {avg_accuracy:.4f}')
print(f'Average Recall (Sensitivity): {avg_recall:.4f}')
print(f'Average Precision: {avg_precision:.4f}')
print(f'Average F1 Score: {avg_f1:.4f}')
print(f'Average Specificity: {avg_specificity:.4f}')

# Plot training history
for fold_idx, history in enumerate(train_histories):
    plt.figure(figsize=(12, 5))
    plt.subplot(1, 2, 1)
    plt.plot(history['accuracy'], label='Train Accuracy')
    plt.plot(history['val_accuracy'], label='Val Accuracy')
    plt.title(f'Model Accuracy for Fold {fold_idx + 1}')
    plt.xlabel('Epoch')
    plt.ylabel('Accuracy')
    plt.legend()

    plt.subplot(1, 2, 2)
    plt.plot(history['loss'], label='Train Loss')
    plt.plot(history['val_loss'], label='Val Loss')
    plt.title(f'Model Loss for Fold {fold_idx + 1}')
    plt.xlabel('Epoch')
    plt.ylabel('Loss')
    plt.legend()

    plt.tight_layout()
    plt.show()
# Out:
# WARNING:tensorflow:From C:\Users\Jaber\anaconda3\Lib\site-packages\keras\src\backend\tensorflow\core.py:192: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# Epoch 1/50
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 362s 28s/step - accuracy: 0.7228 - loss: 1.3049 - val_accuracy: 0.7503 - val_loss: 1.1828 - learning_rate: 0.0010
# Epoch 2/50
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 336s 28s/step - accuracy: 0.7452 - loss: 0.9593 - val_accuracy: 0.8660 - val_loss: 0.8928 - learning_rate: 0.0010
# Epoch 3/50
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 336s 28s/step - accuracy: 0.8819 - loss: 0.8615 - val_accuracy: 0.8650 - val_loss: 0.8584 - learning_rate: 0.0010
# Epoch 4/50
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 335s 28s/step - accuracy: 0.8810 - loss: 0.8319 - val_accuracy: 0.8676 - val_loss: 0.8398 - learning_rate: 0.0010
# Epoch 5/50
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 332s 28s/step - accuracy: 0.8872 - loss: 0.7837 - val_accuracy: 0.8503 - val_loss: 0.6925 - learning_rate: 0.0010
# Epoch 6/50
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 387s 28s/step - accuracy: 0.8763 - loss: 0.5906 - val_accuracy: 0.8702 - val_loss: 0.6324 - learning_rate: 0.0010
# Epoch 7/50
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 328s 28s/step - accuracy: 0.8798 - loss: 0.5899 - val_accuracy: 0.8689 - val_loss: 0.6981 - learning_rate: 0.0010
# Epoch 8/50
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 332s 28s/step - accuracy: 0.8850 - loss: 0.5714 - val_accuracy: 0.8678 - val_loss: 0.6282 - learning_rate: 0.0010
# Epoch 9/50
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 378s 27s/step - accuracy: 0.8827 - loss: 0.5594 - val_accuracy: 0.8688 - val_loss: 0.6823 - learning_rate: 0.0010
# Epoch 10/50
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 381s 27s/step - accuracy: 0.8940 - loss: 0.5186 - val_accuracy: 0.8673 - val_loss: 0.6300 - learning_rate: 0.0010
# Epoch 11/50
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 497s 38s/step - accuracy: 0.8836 - loss: 0.5540 - val_accuracy: 0.8681 - val_loss: 0.6419 - learning_rate: 0.0010
# Epoch 12/50
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 516s 43s/step - accuracy: 0.8908 - loss: 0.5172 - val_accuracy: 0.8677 - val_loss: 0.6223 - learning_rate: 5.0000e-04
# Epoch 13/50
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 570s 48s/step - accuracy: 0.8913 - loss: 0.5251 - val_accuracy: 0.8676 - val_loss: 0.6286 - learning_rate: 2.5000e-04
# Epoch 14/50
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 537s 45s/step - accuracy: 0.8841 - loss: 0.5456 - val_accuracy: 0.8682 - val_loss: 0.6235 - learning_rate: 1.2500e-04
# Epoch 15/50
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 366s 31s/step - accuracy: 0.8932 - loss: 0.5179 - val_accuracy: 0.8682 - val_loss: 0.6246 - learning_rate: 6.2500e-05
# Epoch 16/50
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 364s 30s/step - accuracy: 0.8827 - loss: 0.5544 - val_accuracy: 0.8680 - val_loss: 0.6259 - learning_rate: 3.1250e-05
# Epoch 17/50
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 375s 30s/step - accuracy: 0.8858 - loss: 0.5359 - val_accuracy: 0.8680 - val_loss: 0.6271 - learning_rate: 1.5625e-05
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 47s 12s/step
# Epoch 1/50
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 394s 31s/step - accuracy: 0.6972 - loss: 1.3176 - val_accuracy: 0.7379 - val_loss: 1.2253 - learning_rate: 0.0010
# Epoch 2/50
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 359s 30s/step - accuracy: 0.7470 - loss: 1.0156 - val_accuracy: 0.8816 - val_loss: 0.8294 - learning_rate: 0.0010
# Epoch 3/50
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 355s 30s/step - accuracy: 0.8715 - loss: 0.8710 - val_accuracy: 0.8882 - val_loss: 0.8384 - learning_rate: 0.0010
# Epoch 4/50
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 355s 30s/step - accuracy: 0.8715 - loss: 0.8456 - val_accuracy: 0.8871 - val_loss: 0.8318 - learning_rate: 0.0010
# Epoch 5/50
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 352s 30s/step - accuracy: 0.8662 - loss: 0.8434 - val_accuracy: 0.8715 - val_loss: 0.5901 - learning_rate: 0.0010
# Epoch 6/50
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 357s 30s/step - accuracy: 0.8644 - loss: 0.6797 - val_accuracy: 0.8891 - val_loss: 0.5525 - learning_rate: 0.0010
# Epoch 7/50
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 356s 30s/step - accuracy: 0.8779 - loss: 0.5978 - val_accuracy: 0.8889 - val_loss: 0.5456 - learning_rate: 0.0010
# Epoch 8/50
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 357s 30s/step - accuracy: 0.8749 - loss: 0.6080 - val_accuracy: 0.8875 - val_loss: 0.5453 - learning_rate: 0.0010
# Epoch 9/50
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 363s 30s/step - accuracy: 0.8706 - loss: 0.6114 - val_accuracy: 0.8886 - val_loss: 0.5427 - learning_rate: 0.0010
# Epoch 10/50
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 353s 30s/step - accuracy: 0.8724 - loss: 0.6052 - val_accuracy: 0.8889 - val_loss: 0.5374 - learning_rate: 0.0010
# Epoch 11/50
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 334s 28s/step - accuracy: 0.8733 - loss: 0.6076 - val_accuracy: 0.8890 - val_loss: 0.5488 - learning_rate: 0.0010
# Epoch 12/50
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 349s 29s/step - accuracy: 0.8806 - loss: 0.5812 - val_accuracy: 0.8891 - val_loss: 0.5351 - learning_rate: 5.0000e-04
# Epoch 13/50
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 356s 30s/step - accuracy: 0.8768 - loss: 0.5960 - val_accuracy: 0.8890 - val_loss: 0.5388 - learning_rate: 2.5000e-04
# Epoch 14/50
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 368s 31s/step - accuracy: 0.8848 - loss: 0.5541 - val_accuracy: 0.8893 - val_loss: 0.5349 - learning_rate: 1.2500e-04
# Epoch 15/50
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 370s 31s/step - accuracy: 0.8768 - loss: 0.5834 - val_accuracy: 0.8894 - val_loss: 0.5370 - learning_rate: 6.2500e-05
# Epoch 16/50
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 375s 31s/step - accuracy: 0.8720 - loss: 0.5955 - val_accuracy: 0.8894 - val_loss: 0.5353 - learning_rate: 3.1250e-05
# Epoch 17/50
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 385s 32s/step - accuracy: 0.8874 - loss: 0.5470 - val_accuracy: 0.8894 - val_loss: 0.5344 - learning_rate: 1.5625e-05
# Epoch 18/50
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 369s 31s/step - accuracy: 0.8756 - loss: 0.5886 - val_accuracy: 0.8893 - val_loss: 0.5343 - learning_rate: 7.8125e-06
# Epoch 19/50
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 387s 31s/step - accuracy: 0.8797 - loss: 0.5757 - val_accuracy: 0.8894 - val_loss: 0.5344 - learning_rate: 3.9063e-06
# Epoch 20/50
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 396s 32s/step - accuracy: 0.8795 - loss: 0.5770 - val_accuracy: 0.8894 - val_loss: 0.5344 - learning_rate: 1.9531e-06
# Epoch 21/50
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 446s 32s/step - accuracy: 0.8773 - loss: 0.5809 - val_accuracy: 0.8894 - val_loss: 0.5344 - learning_rate: 9.7656e-07
# Epoch 22/50
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 400s 34s/step - accuracy: 0.8760 - loss: 0.5844 - val_accuracy: 0.8894 - val_loss: 0.5344 - learning_rate: 4.8828e-07
# Epoch 23/50
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 435s 33s/step - accuracy: 0.8783 - loss: 0.5778 - val_accuracy: 0.8894 - val_loss: 0.5344 - learning_rate: 2.4414e-07
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 52s 19s/step
# Epoch 1/50
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 448s 35s/step - accuracy: 0.7372 - loss: 1.3319 - val_accuracy: 0.7440 - val_loss: 0.9213 - learning_rate: 0.0010
# Epoch 2/50
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 400s 33s/step - accuracy: 0.7522 - loss: 0.9106 - val_accuracy: 0.8743 - val_loss: 0.8869 - learning_rate: 0.0010
# Epoch 3/50
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 417s 35s/step - accuracy: 0.8720 - loss: 0.8758 - val_accuracy: 0.8758 - val_loss: 0.8182 - learning_rate: 0.0010
# Epoch 4/50
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 394s 33s/step - accuracy: 0.8760 - loss: 0.8137 - val_accuracy: 0.8569 - val_loss: 0.6690 - learning_rate: 0.0010
# Epoch 5/50
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 394s 33s/step - accuracy: 0.8679 - loss: 0.6254 - val_accuracy: 0.8766 - val_loss: 0.5872 - learning_rate: 0.0010
# WARNING:tensorflow:5 out of the last 5 calls to <function TensorFlowTrainer.make_predict_function.<locals>.one_step_on_data_distributed at 0x0000026769A4AD40> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 1/2 ━━━━━━━━━━━━━━━━━━━━ 36s 37s/stepWARNING:tensorflow:6 out of the last 6 calls to <function TensorFlowTrainer.make_predict_function.<locals>.one_step_on_data_distributed at 0x0000026769A4AD40> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 51s 14s/step
# C:\Users\Jaber\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# Average Accuracy: 0.8342
# Average Recall (Sensitivity): 0.5204
# Average Precision: 0.5032
# Average F1 Score: 0.5115
# Average Specificity: 0.9419
